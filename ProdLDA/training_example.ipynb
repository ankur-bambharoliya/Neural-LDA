# %%
# %matplotlib inline

# %%
from train import train, print_perp
import torch
from hyper_parameters import HyperParameters, USE_CUDA
from prod_lda import ProdLDA
hps = HyperParameters()

# %%
model = ProdLDA(hps)

if USE_CUDA:
    model.cuda()

if hps.optimizer == 'Adam':
    optimizer = torch.optim.Adam(model.parameters(), hps.learning_rate,
                                 betas=(hps.momentum, 0.999))
else:
    optimizer = torch.optim.SGD(model.parameters(),
                                hps.learning_rate, momentum=hps.momentum)

train(model, optimizer)
print_perp(model)
# Out:
# /opt/anaconda3/envs/attn/lib/python3.7/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 1 - Training
# 	Loss : 792.8796289494608 [Reconstruction=777.1626586914062, KL=15.716969405655313]
# Epoch 2 - Training
# 	Loss : 765.6422591757986 [Reconstruction=755.5101005081582, KL=10.132157313085235]
# Epoch 3 - Training
# 	Loss : 746.7618008503872 [Reconstruction=738.0047907196315, KL=8.757012156258643]
# Epoch 4 - Training
# 	Loss : 735.8002602906354 [Reconstruction=728.282235474713, KL=7.518027427977166]
# Epoch 5 - Training
# 	Loss : 729.2406556796184 [Reconstruction=722.8518298663924, KL=6.388822859367438]
# Epoch 6 - Training
# 	Loss : 724.5761691743294 [Reconstruction=719.036830665791, KL=5.53933888410045]
# Epoch 7 - Training
# 	Loss : 722.3150777901168 [Reconstruction=717.4013280277759, KL=4.913749547131293]
# Epoch 8 - Training
# 	Loss : 719.2340285039581 [Reconstruction=714.8678983165099, KL=4.3661302760639025]
# Epoch 9 - Training
# 	Loss : 717.3454508823631 [Reconstruction=713.3845444400754, KL=3.9609081238771964]
# Epoch 10 - Training
# 	Loss : 715.4767893563329 [Reconstruction=711.8307911020464, KL=3.645996239333026]
# Epoch 11 - Training
# 	Loss : 714.6463652754252 [Reconstruction=711.3223633892768, KL=3.3240031457580295]
# Epoch 12 - Training
# 	Loss : 713.9659132155697 [Reconstruction=710.859255090224, KL=3.1066555069611135]
# Epoch 13 - Training
# 	Loss : 712.4956972915514 [Reconstruction=709.5895580190473, KL=2.906141608162264]
# Epoch 14 - Training
# 	Loss : 712.7723394073216 [Reconstruction=710.0475177596101, KL=2.724818660094675]
# Epoch 15 - Training
# 	Loss : 711.3197448190334 [Reconstruction=708.734910272919, KL=2.5848370125863402]
# Epoch 16 - Training
# 	Loss : 710.2564516320692 [Reconstruction=707.7900952364491, KL=2.466356471576522]
# Epoch 17 - Training
# 	Loss : 709.0121011649613 [Reconstruction=706.6618525412231, KL=2.3502480814942217]
# Epoch 18 - Training
# 	Loss : 709.7363127311773 [Reconstruction=707.4233760327364, KL=2.3129350442801955]
# Epoch 19 - Training
# 	Loss : 709.0180202247822 [Reconstruction=706.7120499062327, KL=2.3059693374465]
# Epoch 20 - Training
# 	Loss : 707.8283243094926 [Reconstruction=705.5579223632812, KL=2.2704027796213606]
# Epoch 21 - Training
# 	Loss : 707.1863208872027 [Reconstruction=704.9314815554999, KL=2.2548359442601162]
# Epoch 22 - Training
# 	Loss : 707.1044546481783 [Reconstruction=704.8280523519601, KL=2.276404929372062]
# Epoch 23 - Training
# 	Loss : 707.1118399020845 [Reconstruction=704.8568220560529, KL=2.25501683328004]
# Epoch 24 - Training
# 	Loss : 707.6095130042693 [Reconstruction=705.3246632803858, KL=2.2848481625582266]
# Epoch 25 - Training
# 	Loss : 706.1563858437327 [Reconstruction=703.8602681117775, KL=2.296117381711977]
# Epoch 26 - Training
# 	Loss : 705.9482648731333 [Reconstruction=703.6325634981679, KL=2.315700275708089]
# Epoch 27 - Training
# 	Loss : 706.3002141091675 [Reconstruction=703.9976622995022, KL=2.3025523097114227]
# Epoch 28 - Training
# 	Loss : 706.4312017660226 [Reconstruction=704.1338838560391, KL=2.2973162347236564]
# Epoch 29 - Training
# 	Loss : 705.9953032637064 [Reconstruction=703.647452295354, KL=2.347852249061112]
# Epoch 30 - Training
# 	Loss : 706.5605622688227 [Reconstruction=704.1830014929308, KL=2.3775598960640156]
# Epoch 31 - Training
# 	Loss : 705.6053318259991 [Reconstruction=703.2103257981022, KL=2.3950058169069544]
# Epoch 32 - Training
# 	Loss : 705.7287657071004 [Reconstruction=703.3235319694586, KL=2.405233387398509]
# Epoch 33 - Training
# 	Loss : 705.2947636157011 [Reconstruction=702.8685751045699, KL=2.426189665245799]
# Epoch 34 - Training
# 	Loss : 704.887571081651 [Reconstruction=702.4561222042657, KL=2.431450155983984]
# Epoch 35 - Training
# 	Loss : 706.7058588888793 [Reconstruction=704.2521227271156, KL=2.4537385628286716]
# Epoch 36 - Training
# 	Loss : 705.6009016458967 [Reconstruction=703.1226984884887, KL=2.478203868443987]
# Epoch 37 - Training
# 	Loss : 704.4645501871024 [Reconstruction=701.9289024150477, KL=2.5356485695965523]
# Epoch 38 - Training
# 	Loss : 704.4828685659223 [Reconstruction=701.8937909961802, KL=2.5890779516338247]
# Epoch 39 - Training
# 	Loss : 703.9328083949806 [Reconstruction=701.3260884242775, KL=2.6067186520162937]
# Epoch 40 - Training
# 	Loss : 704.3808620756706 [Reconstruction=701.8043264203367, KL=2.57653449699942]
# Epoch 41 - Training
# 	Loss : 703.5636061946902 [Reconstruction=700.9546200912611, KL=2.6089849050066114]
# Epoch 42 - Training
# 	Loss : 703.7268671356471 [Reconstruction=701.0959299813329, KL=2.630934770128368]
# Epoch 43 - Training
# 	Loss : 703.7164041974903 [Reconstruction=701.0615350503837, KL=2.6548683052569366]
# Epoch 44 - Training
# 	Loss : 703.6364178952917 [Reconstruction=700.9323668353326, KL=2.7040518596109036]
# Epoch 45 - Training
# 	Loss : 703.0403572015002 [Reconstruction=700.2671182007916, KL=2.7732417857752436]
# Epoch 46 - Training
# 	Loss : 703.2406870073977 [Reconstruction=700.4358442188365, KL=2.8048410922025155]
# Epoch 47 - Training
# 	Loss : 702.6285343676542 [Reconstruction=699.7978766787369, KL=2.8306593346384776]
# Epoch 48 - Training
# 	Loss : 702.075782168228 [Reconstruction=699.1775717946281, KL=2.898210029686447]
# Epoch 49 - Training
# 	Loss : 702.009302730054 [Reconstruction=699.0649538293349, KL=2.944348896499229]
# Epoch 50 - Training
# 	Loss : 702.141189980296 [Reconstruction=699.1437469752489, KL=2.9974436654453784]
# Epoch 51 - Training
# 	Loss : 701.7885728684147 [Reconstruction=698.7391792229846, KL=3.049396348210563]
# Epoch 52 - Training
# 	Loss : 701.9858517267007 [Reconstruction=698.8643423434908, KL=3.1215060453499315]
# Epoch 53 - Training
# 	Loss : 702.0751737071349 [Reconstruction=698.8947856531734, KL=3.1803884042047823]
# Epoch 54 - Training
# 	Loss : 700.9087049096031 [Reconstruction=697.6970050102841, KL=3.211702336252263]
# Epoch 55 - Training
# 	Loss : 701.7566212341849 [Reconstruction=698.5027247065991, KL=3.253898160647502]
# Epoch 56 - Training
# 	Loss : 702.1479384160675 [Reconstruction=698.8499207623237, KL=3.298014891886078]
# Epoch 57 - Training
# 	Loss : 700.6855944068031 [Reconstruction=697.3443508992153, KL=3.34124511322089]
# Epoch 58 - Training
# 	Loss : 702.5967898748618 [Reconstruction=699.2081493276411, KL=3.388641566301869]
# Epoch 59 - Training
# 	Loss : 701.0806441855642 [Reconstruction=697.6491842354293, KL=3.431459236988979]
# Epoch 60 - Training
# 	Loss : 701.4300010478602 [Reconstruction=697.9908152892526, KL=3.43918362338986]
# Epoch 61 - Training
# 	Loss : 701.0424648048603 [Reconstruction=697.5746143982474, KL=3.4678503855139806]
# Epoch 62 - Training
# 	Loss : 700.6550120125829 [Reconstruction=697.1470733912645, KL=3.5079382035584574]
# Epoch 63 - Training
# 	Loss : 700.3492258797704 [Reconstruction=696.7935304894911, KL=3.555695092783565]
# Epoch 64 - Training
# 	Loss : 700.61275434916 [Reconstruction=697.0198383162507, KL=3.592915792380814]
# Epoch 65 - Training
# 	Loss : 700.2781380172324 [Reconstruction=696.6545164395222, KL=3.623620997487971]
# Epoch 66 - Training
# 	Loss : 699.8012962678893 [Reconstruction=696.148660305327, KL=3.652633846333597]
# Epoch 67 - Training
# 	Loss : 699.4261428697974 [Reconstruction=695.7280308546218, KL=3.698109010679532]
# Epoch 68 - Training
# 	Loss : 700.334391366064 [Reconstruction=696.6118226177924, KL=3.72256898669015]
# Epoch 69 - Training
# 	Loss : 698.9460470824115 [Reconstruction=695.1951550509023, KL=3.75089345991084]
# Epoch 70 - Training
# 	Loss : 699.0587701037922 [Reconstruction=695.2669893788026, KL=3.7917812039366865]
# Epoch 71 - Training
# 	Loss : 699.5205415708829 [Reconstruction=695.6988776552994, KL=3.8216662385822397]
# Epoch 72 - Training
# 	Loss : 701.0864708824495 [Reconstruction=697.223624170354, KL=3.862843106278276]
# Epoch 73 - Training
# 	Loss : 699.6501986073182 [Reconstruction=695.754129055327, KL=3.8960690941430824]
# Epoch 74 - Training
# 	Loss : 699.5925136329853 [Reconstruction=695.7053468417278, KL=3.887165284789769]
# Epoch 75 - Training
# 	Loss : 699.5457115510924 [Reconstruction=695.6640344130254, KL=3.881678121279826]
# Epoch 76 - Training
# 	Loss : 698.7528405653692 [Reconstruction=694.8462880902586, KL=3.9065517788439728]
# Epoch 77 - Training
# 	Loss : 699.8541940334624 [Reconstruction=695.9330230982957, KL=3.9211693696216146]
# Epoch 78 - Training
# 	Loss : 699.4302092695658 [Reconstruction=695.455262310737, KL=3.974947745821117]
# Epoch 79 - Training
# 	Loss : 700.2710285017976 [Reconstruction=696.245031576241, KL=4.025994486513391]
# Epoch 80 - Training
# 	Loss : 700.1141497856747 [Reconstruction=696.0501627964256, KL=4.063985685331631]
# Epoch 81 - Training
# 	Loss : 698.568278084814 [Reconstruction=694.4260567184043, KL=4.142220273482061]
# Epoch 82 - Training
# 	Loss : 698.7426995471516 [Reconstruction=694.5614051481264, KL=4.181293993924571]
# Epoch 83 - Training
# 	Loss : 698.614322088461 [Reconstruction=694.4397834170181, KL=4.174539080763285]
# Epoch 84 - Training
# 	Loss : 700.2843792670596 [Reconstruction=696.0814395330649, KL=4.2029423376100254]
# Epoch 85 - Training
# 	Loss : 699.662250620074 [Reconstruction=695.4041207912749, KL=4.258127731559551]
# Epoch 86 - Training
# 	Loss : 698.833719169144 [Reconstruction=694.5247186981471, KL=4.309000850778766]
# Epoch 87 - Training
# 	Loss : 698.8281268904694 [Reconstruction=694.5066585034396, KL=4.321466399505075]
# Epoch 88 - Training
# 	Loss : 697.7857233908325 [Reconstruction=693.4445384877973, KL=4.3411860803587246]
# Epoch 89 - Training
# 	Loss : 699.3027662429134 [Reconstruction=694.9181340310425, KL=4.3846309332721]
# Epoch 90 - Training
# 	Loss : 698.2775738471378 [Reconstruction=693.8525639086698, KL=4.425007950943129]
# Epoch 91 - Training
# 	Loss : 698.9054538422981 [Reconstruction=694.4428700134818, KL=4.462583415276181]
# Epoch 92 - Training
# 	Loss : 697.5165999420976 [Reconstruction=693.0162742412195, KL=4.500324388520908]
# Epoch 93 - Training
# 	Loss : 698.4810399418384 [Reconstruction=693.9691078388586, KL=4.5119339934492535]
# Epoch 94 - Training
# 	Loss : 699.4393102595236 [Reconstruction=694.908682764104, KL=4.5306299640014105]
# Epoch 95 - Training
# 	Loss : 697.8041111768874 [Reconstruction=693.259204425643, KL=4.544909029935313]
# Epoch 96 - Training
# 	Loss : 697.294875153398 [Reconstruction=692.6998898666517, KL=4.594988202626726]
# Epoch 97 - Training
# 	Loss : 698.2965806269012 [Reconstruction=693.6808252925366, KL=4.615752971277828]
# Epoch 98 - Training
# 	Loss : 697.8906328319448 [Reconstruction=693.2421005384057, KL=4.6485310486987625]
# Epoch 99 - Training
# 	Loss : 698.9016648014035 [Reconstruction=694.2209399738143, KL=4.680720447439008]
# Epoch 100 - Training
# 	Loss : 697.8819698907632 [Reconstruction=693.1732015694137, KL=4.7087674984889745]
# The approximated perplexity is:  1113.4692836147526
